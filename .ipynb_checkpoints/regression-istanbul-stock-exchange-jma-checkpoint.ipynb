# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

from sklearn.linear_model import LinearRegression

# %matplotlib inline

# %%
df = pd.read_csv("../input/istanbul-stock-exchange/istanbul_stock_exchange.csv")
df = df.set_index("date")
df.head()
# Out:
#           TL BASED ISE  USD BASED ISE        SP       DAX      FTSE    NIKKEI  \
# date
# 5-Jan-09      0.035754       0.038376 -0.004679  0.002193  0.003894  0.000000
# 6-Jan-09      0.025426       0.031813  0.007787  0.008455  0.012866  0.004162
# 7-Jan-09     -0.028862      -0.026353 -0.030469 -0.017833 -0.028735  0.017293
# 8-Jan-09     -0.062208      -0.084716  0.003391 -0.011726 -0.000466 -0.040061
# 9-Jan-09      0.009860       0.009658 -0.021533 -0.019873 -0.012710 -0.004474
#
#            BOVESPA        EU        EM
# date
# 5-Jan-09  0.031190  0.012698  0.028524
# 6-Jan-09  0.018920  0.011341  0.008773
# 7-Jan-09 -0.035899 -0.017073 -0.020015
# 8-Jan-09  0.028283 -0.005561 -0.019424
# 9-Jan-09 -0.009764 -0.010989 -0.007802

# %%
sns.pairplot(df.iloc[:, 1:])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 536 entries, 5-Jan-09 to 22-Feb-11
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   TL BASED ISE   536 non-null    float64
#  1   USD BASED ISE  536 non-null    float64
#  2   SP             536 non-null    float64
#  3   DAX            536 non-null    float64
#  4   FTSE           536 non-null    float64
#  5   NIKKEI         536 non-null    float64
#  6   BOVESPA        536 non-null    float64
#  7   EU             536 non-null    float64
#  8   EM             536 non-null    float64
# dtypes: float64(9)
# memory usage: 61.9+ KB

# %%
plt.figure(figsize=(10, 5))
df.plot.line()

# %%
df.columns
# Out:
# Index(['TL BASED ISE', 'USD BASED ISE', 'SP', 'DAX', 'FTSE', 'NIKKEI',
#        'BOVESPA', 'EU', 'EM'],
#       dtype='object')

# %%
n_train = 525

# %%
training = df.iloc[:n_train, :]
training.tail()
# Out:
#           TL BASED ISE  USD BASED ISE        SP       DAX      FTSE    NIKKEI  \
# date
# 1-Feb-11      0.024116       0.035257  0.016556  0.014976  0.016057  0.003567
# 2-Feb-11      0.007447       0.014239 -0.002726 -0.000083  0.007075  0.017641
# 3-Feb-11     -0.024478      -0.027850  0.002351  0.001392 -0.002804 -0.002489
# 4-Feb-11      0.024507       0.013959  0.002880  0.003127  0.002354  0.010695
# 7-Feb-11     -0.006196       0.008553  0.006221  0.009298  0.008898  0.004591
#
#            BOVESPA        EU        EM
# date
# 1-Feb-11  0.018926  0.015089  0.006224
# 2-Feb-11 -0.017230  0.001618  0.003631
# 3-Feb-11  0.001154 -0.002883  0.000476
# 4-Feb-11 -0.022662  0.002761 -0.003185
# 7-Feb-11  0.001424  0.008217 -0.003346

# %%
testing = df.iloc[n_train:, :]
testing.head(10)
# Out:
#            TL BASED ISE  USD BASED ISE        SP       DAX      FTSE  \
# date
# 8-Feb-11       0.005356       0.006886  0.004176  0.005425  0.006638
# 9-Feb-11       0.004823      -0.003255 -0.002790 -0.000320 -0.006423
# 10-Feb-11     -0.017664      -0.024921  0.000749  0.002644 -0.005351
# 11-Feb-11      0.004782       0.006418  0.005492  0.004204  0.007101
# 14-Feb-11     -0.002498       0.000405  0.002382  0.003444 -0.000462
# 15-Feb-11      0.003606       0.000893 -0.003240  0.000461 -0.003803
# 16-Feb-11      0.008599       0.013400  0.006238  0.001925  0.007952
# 17-Feb-11      0.009310       0.015977  0.003071 -0.001186  0.000345
# 18-Feb-11      0.000191      -0.001653  0.001923  0.002872 -0.000723
# 21-Feb-11     -0.013069      -0.013706 -0.020742 -0.014239 -0.011275
#
#              NIKKEI   BOVESPA        EU        EM
# date
# 8-Feb-11   0.004140  0.006238  0.003980 -0.004499
# 9-Feb-11  -0.001708 -0.023895 -0.003024 -0.014249
# 10-Feb-11 -0.001148  0.005590 -0.003742 -0.014760
# 11-Feb-11  0.011241  0.018077  0.004727  0.003931
# 14-Feb-11  0.000000  0.012123  0.000169  0.013448
# 15-Feb-11  0.001968 -0.003266 -0.000550 -0.001430
# 16-Feb-11  0.005717  0.018371  0.006975  0.003039
# 17-Feb-11  0.002620  0.001686 -0.000581  0.001039
# 18-Feb-11  0.000568  0.005628  0.000572  0.006938
# 21-Feb-11  0.001358 -0.011942 -0.012615 -0.000958

# %%
X_train = training.iloc[:, 1:]
y_train = training.iloc[:, 0]

# %%
X_train.head()
# Out:
#           USD BASED ISE        SP       DAX      FTSE    NIKKEI   BOVESPA  \
# date
# 5-Jan-09       0.038376 -0.004679  0.002193  0.003894  0.000000  0.031190
# 6-Jan-09       0.031813  0.007787  0.008455  0.012866  0.004162  0.018920
# 7-Jan-09      -0.026353 -0.030469 -0.017833 -0.028735  0.017293 -0.035899
# 8-Jan-09      -0.084716  0.003391 -0.011726 -0.000466 -0.040061  0.028283
# 9-Jan-09       0.009658 -0.021533 -0.019873 -0.012710 -0.004474 -0.009764
#
#                 EU        EM
# date
# 5-Jan-09  0.012698  0.028524
# 6-Jan-09  0.011341  0.008773
# 7-Jan-09 -0.017073 -0.020015
# 8-Jan-09 -0.005561 -0.019424
# 9-Jan-09 -0.010989 -0.007802

# %%
y_train
# Out:
# date
# 5-Jan-09    0.035754
# 6-Jan-09    0.025426
# 7-Jan-09   -0.028862
# 8-Jan-09   -0.062208
# 9-Jan-09    0.009860
#               ...
# 1-Feb-11    0.024116
# 2-Feb-11    0.007447
# 3-Feb-11   -0.024478
# 4-Feb-11    0.024507
# 7-Feb-11   -0.006196
# Name: TL BASED ISE, Length: 525, dtype: float64

# %%
X_train = X_train.values

# %%
X_test = testing.iloc[:, 1:].values
y_test = testing.iloc[:, 0].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
lr.intercept_, lr.coef_
# Out:
# (0.0005359288668122023,
#  array([ 0.7912421 , -0.02781446,  0.06546184,  0.11617357, -0.09066996,
#          0.08657076, -0.12501128, -0.23090677]))

# %%
lr.score(X_test, y_test)
# Out:
# 0.878993659890135

# %%
y_test_pred = lr.predict(X_test)

# %%
pd.DataFrame({"true": y_test, "predict": y_test_pred})
# Out:
#         true   predict
# 0   0.005356  0.007700
# 1   0.004823 -0.000975
# 2  -0.017664 -0.015188
# 3   0.004782  0.005609
# 4  -0.002498 -0.001115
# 5   0.003606  0.000859
# 6   0.008599  0.011513
# 7   0.009310  0.012796
# 8   0.000191 -0.001959
# 9  -0.013069 -0.011333
# 10 -0.007246 -0.010678

# %%
residuals = y_test_pred - y_test
plt.scatter(range(len(residuals)), residuals)
plt.xticks(range(len(residuals)), 
           df.iloc[n_train:, ].index, rotation = 90)
plt.tight_layout()
plt.hlines([0], xmin=0, xmax=10, linestyles = "--")
plt.xlabel("Date")
plt.ylabel("Residual")
# Out:
# Text(5.875, 0.5, 'Residual')

# %%
residuals
# Out:
# array([ 0.00234466, -0.00579764,  0.00247666,  0.00082648,  0.00138262,
#        -0.00274766,  0.00291414,  0.00348564, -0.00214989,  0.00173652,
#        -0.00343151])

# %%
def rmse(y_true, y_pred):
    return np.sqrt(np.mean((y_true - y_pred) ** 2))

# %%
rmse(y_test, y_test_pred)
# Out:
# 0.0029456114998142107

# %%
df.columns
# Out:
# Index(['TL BASED ISE', 'USD BASED ISE', 'SP', 'DAX', 'FTSE', 'NIKKEI',
#        'BOVESPA', 'EU', 'EM'],
#       dtype='object')

# %%
df.head()
# Out:
#           TL BASED ISE  USD BASED ISE        SP       DAX      FTSE    NIKKEI  \
# date
# 5-Jan-09      0.035754       0.038376 -0.004679  0.002193  0.003894  0.000000
# 6-Jan-09      0.025426       0.031813  0.007787  0.008455  0.012866  0.004162
# 7-Jan-09     -0.028862      -0.026353 -0.030469 -0.017833 -0.028735  0.017293
# 8-Jan-09     -0.062208      -0.084716  0.003391 -0.011726 -0.000466 -0.040061
# 9-Jan-09      0.009860       0.009658 -0.021533 -0.019873 -0.012710 -0.004474
#
#            BOVESPA        EU        EM
# date
# 5-Jan-09  0.031190  0.012698  0.028524
# 6-Jan-09  0.018920  0.011341  0.008773
# 7-Jan-09 -0.035899 -0.017073 -0.020015
# 8-Jan-09  0.028283 -0.005561 -0.019424
# 9-Jan-09 -0.009764 -0.010989 -0.007802

# %%
df.shape
# Out:
# (536, 9)

# %%
df_lagged = df.shift(1)
df_lagged.shape
# Out:
# (536, 9)

# %%
df_lagged.head()
# Out:
#           TL BASED ISE  USD BASED ISE        SP       DAX      FTSE    NIKKEI  \
# date
# 5-Jan-09           NaN            NaN       NaN       NaN       NaN       NaN
# 6-Jan-09      0.035754       0.038376 -0.004679  0.002193  0.003894  0.000000
# 7-Jan-09      0.025426       0.031813  0.007787  0.008455  0.012866  0.004162
# 8-Jan-09     -0.028862      -0.026353 -0.030469 -0.017833 -0.028735  0.017293
# 9-Jan-09     -0.062208      -0.084716  0.003391 -0.011726 -0.000466 -0.040061
#
#            BOVESPA        EU        EM
# date
# 5-Jan-09       NaN       NaN       NaN
# 6-Jan-09  0.031190  0.012698  0.028524
# 7-Jan-09  0.018920  0.011341  0.008773
# 8-Jan-09 -0.035899 -0.017073 -0.020015
# 9-Jan-09  0.028283 -0.005561 -0.019424

# %%
df_joined = pd.concat([df, df_lagged], axis=1).iloc[1:, :]

# %%
df_joined.head()
# Out:
#            TL BASED ISE  USD BASED ISE        SP       DAX      FTSE  \
# date
# 6-Jan-09       0.025426       0.031813  0.007787  0.008455  0.012866
# 7-Jan-09      -0.028862      -0.026353 -0.030469 -0.017833 -0.028735
# 8-Jan-09      -0.062208      -0.084716  0.003391 -0.011726 -0.000466
# 9-Jan-09       0.009860       0.009658 -0.021533 -0.019873 -0.012710
# 12-Jan-09     -0.029191      -0.042361 -0.022823 -0.013526 -0.005026
#
#              NIKKEI   BOVESPA        EU        EM  TL BASED ISE  \
# date
# 6-Jan-09   0.004162  0.018920  0.011341  0.008773      0.035754
# 7-Jan-09   0.017293 -0.035899 -0.017073 -0.020015      0.025426
# 8-Jan-09  -0.040061  0.028283 -0.005561 -0.019424     -0.028862
# 9-Jan-09  -0.004474 -0.009764 -0.010989 -0.007802     -0.062208
# 12-Jan-09 -0.049039 -0.053849 -0.012451 -0.022630      0.009860
#
#            USD BASED ISE        SP       DAX      FTSE    NIKKEI   BOVESPA  \
# date
# 6-Jan-09        0.038376 -0.004679  0.002193  0.003894  0.000000  0.031190
# 7-Jan-09        0.031813  0.007787  0.008455  0.012866  0.004162  0.018920
# 8-Jan-09       -0.026353 -0.030469 -0.017833 -0.028735  0.017293 -0.035899
# 9-Jan-09       -0.084716  0.003391 -0.011726 -0.000466 -0.040061  0.028283
# 12-Jan-09       0.009658 -0.021533 -0.019873 -0.012710 -0.004474 -0.009764
#
#                  EU        EM
# date
# 6-Jan-09   0.012698  0.028524
# 7-Jan-09   0.011341  0.008773
# 8-Jan-09  -0.017073 -0.020015
# 9-Jan-09  -0.005561 -0.019424
# 12-Jan-09 -0.010989 -0.007802

# %%
df_joined.shape
# Out:
# (535, 18)

# %%
training = df_joined.iloc[:n_train, :]
testing = df_joined.iloc[n_train:, :]
X_train = training.iloc[:, 1:]
y_train = training.iloc[:, 0]
X_test = testing.iloc[:, 1:].values
y_test = testing.iloc[:, 0].values
lr.fit(X_train, y_train)
print("R2", lr.score(X_test, y_test))
y_test_pred = lr.predict(X_test)
rmse(y_test, y_test_pred)
# Out:
# R2 0.8989799584239195
# 0.0027580065484083625
